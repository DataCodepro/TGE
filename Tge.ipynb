# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
#import streamlit as st

# Load the dataset
data = pd.read_csv('TGE_price.csv')

data.head()
# Out:
#    tge_year           name           narrative         type  inst_ico  \
# 0      2024         COOKIE                 AI       Altcoin         1
# 1      2024         BUBBLE              GAMING       GameFi         1
# 2      2024            MON                 ALT      Altcoin         0
# 3      2024          CLOUD               WEB 3  Application         1
# 4      2017  ADA (Cardano)  BLOCKCHAIN / LAYER      Altcoin         1
#
#    comm_ico  listing_price  inst_vesting_perc  pub_vesting_perc    cex_1  \
# 0         0         0.1135               2.00              12.5    bybit
# 1         1         0.0200              18.50              30.0    bybit
# 2         1         0.3900               0.00              30.0    BingX
# 3         1         0.3200              13.00              30.0    Bybit
# 4         0         0.2000              51.61               0.0  Binance
#
#     cex_2   cex_3  x_comm  hr1_high  hr1_low  hr2_high  hr2_low  hr3_high  \
# ...

# %%
data = data.applymap(lambda x: x.upper() if isinstance(x, str) else x)
# Out:
# C:\Users\simeo\AppData\Local\Temp\ipykernel_3560\4009959337.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = data.applymap(lambda x: x.upper() if isinstance(x, str) else x)

# %%
data.shape
# Out:
# (47, 19)

# %%
data['narrative'].unique()
# Out:
# array(['AI ', 'GAMING', 'ALT', 'WEB 3', 'BLOCKCHAIN / LAYER', 'LAYER',
#        'PROTOCOL', 'STORAGE', 'BLOCKCHAIN', 'GAMING / WEB 3',
#        'WEB 3 / APPLICATION', 'LAYER / PROTOCOL', 'DEFI', 'APPLICATION',
#        'LENDING PLATFORM', 'LAYER / DEX', 'DEX', 'PROTOCOL / DEX',
#        'AI / APPLICATION', 'LIQUID STAKING / NODES', 'DEFI / GAMING',
#        'BLOCKCHAIN / NODES', 'STORAGE / PROTOCOL', 'LAYER 2'],
#       dtype=object)

# %%
data['type'].unique()
# Out:
# array(['ALTCOIN', 'GAMEFI', 'APPLICATION', 'BLOCKCHAIN', 'DEFI'],
#       dtype=object)

# %%
data['cex_1'].unique()
# Out:
# array(['BYBIT', 'BINGX', 'BINANCE', 'COINBASE', 'UPBIT', 'SOUTHXCHANGE',
#        'MEXC', 'OKX', 'KUCOIN', 'GATE.IO', 'UNISWAP', 'METAMASK',
#        'PANCAKESWAP'], dtype=object)

# %%
data['cex_2'].unique()
# Out:
# array(['MEXC', 'BITGET', 'BTSE', 'KRAKEN', 'OKX', 'BYBIT', 'BITMARK',
#        'BINANCE', 'HTX', 'STAKECUBE', 'UPBIT', 'NONE', 'HOTCOIN',
#        'FIRESTARTER', 'COINBASE', 'PRIMEXBT', 'GATE.IO', 'DOJOSWAP',
#        'UNISWAP', 'KUCOIN', 'BYBIT '], dtype=object)

# %%
data['cex_3'].unique()
# Out:
# array(['KUCOIN', 'HTX', 'WEEX', 'OKX', 'BYBIT', 'KRAKEN', 'P2B',
#        'GATE.IO', 'FRIEEXCHANGE', 'BINGX', 'BITGET', 'NONE', 'POLONIEX',
#        'BINANCE', 'UNISWAP', 'ASTROPORT', 'COINBASE', 'MATCHA', 'ORCA'],
#       dtype=object)

# %%
data['name'].unique()
# Out:
# array(['COOKIE', 'BUBBLE', 'MON', 'CLOUD', 'ADA (CARDANO)',
#        'POLKADOT (DOT)', 'RETIK', 'FIL (FILECOIN)', 'NEO', 'ALIAS', 'ARK',
#        'STRAX', 'CMPS', 'MATR1X FIRE', 'QUANT', 'QORPO', 'ARTFI',
#        'BLOCKLORDS', 'QUARKCHAIN', 'QITCOIN', 'MYTHOS', 'RENDER', 'RENZO',
#        'AGORAHUB', 'INJEX FINANCE', 'SOLANA', 'SEI NETWORK', 'CODYFIGHT',
#        'LAYER3', 'SUI', 'SUSHI', 'BOUNCEBIT', 'ETHENA', 'ARCADE',
#        'ORDERLY NETWORK', 'NATIX NETWORK', 'MIRADA AI', 'ROCKET POOL',
#        'ROCO FINANCE', 'RONIN', 'REN PROTOCOL', 'NILLION',
#        'TON (THE OPEN NETWORK)', 'TRON', 'TNA', 'TAIKO',
#        'RADIANT CAPITAL'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tge_year           47 non-null     int64
#  1   name               47 non-null     object
#  2   narrative          47 non-null     object
#  3   type               47 non-null     object
#  4   inst_ico           47 non-null     int64
#  5   comm_ico           47 non-null     int64
#  6   listing_price      47 non-null     float64
#  7   inst_vesting_perc  45 non-null     float64
#  8   pub_vesting_perc   46 non-null     float64
#  9   cex_1              47 non-null     object
#  10  cex_2              47 non-null     object
#  11  cex_3              47 non-null     object
#  12  x_comm             47 non-null     int64
#  13  hr1_high           46 non-null     float64
#  14  hr1_low            47 non-null     float64
#  15  hr2_high           47 non-null     float64
# ...

# %%
data.isnull().sum()
# Out:
# tge_year             0
# name                 0
# narrative            0
# type                 0
# inst_ico             0
# comm_ico             0
# listing_price        0
# inst_vesting_perc    2
# pub_vesting_perc     1
# cex_1                0
# cex_2                0
# cex_3                0
# x_comm               0
# hr1_high             1
# hr1_low              0
# hr2_high             0
# hr2_low              0
# hr3_high             0
# hr3_low              0
# dtype: int64

# %%
data.fillna(0,inplace=True)

# %%
# Mapping categorical columns to numerical values using factorize
data['narrative'], _ = pd.factorize(data['narrative'])
data['type'], _ = pd.factorize(data['type'])
data['cex_1'], _ = pd.factorize(data['cex_1'])
data['cex_2'], _ = pd.factorize(data['cex_2'])
data['cex_3'], _ = pd.factorize(data['cex_3'])
data.head()
# Out:
#    tge_year           name  narrative  type  inst_ico  comm_ico  \
# 0      2024         COOKIE          0     0         1         0
# 1      2024         BUBBLE          1     1         1         1
# 2      2024            MON          2     0         0         1
# 3      2024          CLOUD          3     2         1         1
# 4      2017  ADA (CARDANO)          4     0         1         0
#
#    listing_price  inst_vesting_perc  pub_vesting_perc  cex_1  cex_2  cex_3  \
# 0         0.1135               2.00              12.5      0      0      0
# 1         0.0200              18.50              30.0      0      1      1
# 2         0.3900               0.00              30.0      1      2      2
# 3         0.3200              13.00              30.0      0      3      3
# 4         0.2000              51.61               0.0      2      4      4
#
#    x_comm  hr1_high  hr1_low  hr2_high  hr2_low  hr3_high  hr3_low
# ...

# %%
# Define features and target variables
features = data.drop(columns=['hr1_high', 'hr1_low', 'hr2_high', 'hr2_low', 'hr3_high', 'hr3_low','name','tge_year'])
targets = data[['hr1_high', 'hr1_low', 'hr2_high', 'hr2_low', 'hr3_high', 'hr3_low']]
y = data['hr1_high']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=42)
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.feature_selection import mutual_info_regression
import plotly.express as px

# %%
# Train a Random Forest model
model =RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate the mean squared error
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 5.128596363833331

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, r2_score
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test,y_pred)
print(mae)
print(mape)
print(r2_score(y_test,y_pred))
# Out:
# 1.3859683333333337
# 457242964167562.7
# 0.7856138750333795
